# %%
import os
import time

from selenium import webdriver
from selenium.webdriver.common.by import By

chromedriver_path = "C:\\Users\\Araf\\Desktop\\Script\\chromedriver_win32"
os.environ['PATH'] += chromedriver_path

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(40)

driver.get("https://vjudge.net/")
# do login manually

# %%
driver.get("https://vjudge.net/user/kzvd4729#")
# go to the profile page and toggle

# %%
data = driver.find_elements(By.TAG_NAME, "tr")
data = data[27] # Uva is in 27

# %%
problem_links = []
links = data.find_elements(By.CSS_SELECTOR, "a[href*='/']")
for link in links:
    problem_links.append(link.get_attribute("href"))

# %%
# len of problme_links = 204
lt = 167
rt = 203
for i in range(lt, rt+1):
    prb = problem_links[i]
    driver.get(prb)
    time.sleep(5)
    
    t_row = driver.find_elements(By.TAG_NAME, "tr")
    t_row = t_row[1:]
    
    c_sub = 0
    for row in t_row:
        t_col = row.find_elements(By.TAG_NAME, "td")
        title = t_col[1].text.strip()+" - "+t_col[2].text.strip()
        p_link = (t_col[2].find_element(By.CSS_SELECTOR, "a[href*='problem']")).get_attribute("href")
        verdict = t_col[4].text.strip()
        run_time = t_col[5].text.strip()
        mem_used = t_col[6].text.strip()
        language = t_col[8].text.strip()
        
        btn = t_col[4].find_element(By.CSS_SELECTOR, ".view-solution")
        btn.click()
        time.sleep(2)
        
        code = driver.find_element(By.TAG_NAME, "code").text
        created = driver.find_element(By.CSS_SELECTOR, ".Submitted").text.strip()
        
        close = driver.find_element(By.CSS_SELECTOR, ".fa-close")
        close.click()
        time.sleep(2)
        
        
        table_data=[
            [f'*  @author: kzvd4729', f'created: {created}'],
            [f'*  solution_verdict: {verdict}', f'language: {language}'],
            [f'*  run_time: {run_time}', f'memory_used: {mem_used}']
        ]
        printer = '/****************************************************************************************\n'
        for row in table_data:
            printer+=("{: <60} {: <50}".format(*row))+'\n'
        printer += f"*  problem: {p_link}\n"
        printer +='****************************************************************************************/\n'

        printer += code
        
        if len(printer)<590:
            print("got one bad")
            exit()
            
        current = f"UVa/{title}"
        if not os.path.exists(current):
            os.mkdir(current)
            
        
        current = current+f'/{verdict}'
        for j in range(1, 1000):
            if (j==1):
                now = current+'.cpp'
            else:
                now = current+f' ({j}).cpp'

            if not os.path.exists(now):
                with open(now, 'w', encoding='utf8') as f:
                    f.write(printer)
                f.close()

                break
        c_sub+=1
        print(f"done {i}:  {c_sub}/{len(t_row)}   {title}")
# Out:
# done 167:  1/4   UVA - 12060
# done 167:  2/4   UVA - 12060
# done 167:  3/4   UVA - 12060
# done 167:  4/4   UVA - 12060
# done 168:  1/1   UVA - 12071
# done 169:  1/1   UVA - 12086
# done 170:  1/1   UVA - 12338
# done 171:  1/1   UVA - 12376
# done 172:  1/2   UVA - 12403
# done 172:  2/2   UVA - 12403
# done 173:  1/1   UVA - 12461
# done 174:  1/1   UVA - 12463
# done 175:  1/5   UVA - 12467
# done 175:  2/5   UVA - 12467
# done 175:  3/5   UVA - 12467
# done 175:  4/5   UVA - 12467
# done 175:  5/5   UVA - 12467
# done 176:  1/6   UVA - 12470
# done 176:  2/6   UVA - 12470
# done 176:  3/6   UVA - 12470
# done 176:  4/6   UVA - 12470
# done 176:  5/6   UVA - 12470
# done 176:  6/6   UVA - 12470
# done 177:  1/6   UVA - 12494
# done 177:  2/6   UVA - 12494
# done 177:  3/6   UVA - 12494
# done 177:  4/6   UVA - 12494
# done 177:  5/6   UVA - 12494
# done 177:  6/6   UVA - 12494
# done 178:  1/2   UVA - 12563
# done 178:  2/2   UVA - 12563
# done 179:  1/1   UVA - 12596
