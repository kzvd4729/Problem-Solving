# %%
import os
import time

from selenium import webdriver
from selenium.webdriver.common.by import By

chromedriver_path = "C:\\Users\\Araf\\Desktop\\Script\\chromedriver_win32"
os.environ['PATH'] += chromedriver_path

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(40)

driver.get("https://codeforces.com/enter")

# %%
login = driver.find_element(By.ID, "handleOrEmail")
password = driver.find_element(By.ID, "password")

handle = 'kzvd4729'
_pass = 'earth_is_flat'

login.send_keys(handle)
password.send_keys(_pass)
time.sleep(3)
btn = driver.find_element(By.CSS_SELECTOR, ".submit")
btn.click()
time.sleep(3)

# %%
lt = 1
rt = 145
for i in range(lt, rt+1):  
    driver.get(f"https://codeforces.com/submissions/{handle}/page/{i}")
    time.sleep(7)
    count = 0
    
    table_row = driver.find_elements(By.TAG_NAME, "tr") # every row is selected
    table_row = table_row[1:-2]
    
    ii = 0
    t_len = len(table_row)
    while ii<t_len:
        row = table_row[ii]
        table_col = row.find_elements(By.TAG_NAME, "td")

        subid = table_col[0].text
        subid = subid.strip()
        
        author = table_col[2].text
        author = author.strip()

        created = table_col[1].text
        if "UTC" in created:
            ind = created.find("UTC")
            created = created[:ind]
        created = created.strip()

        problem_title = table_col[3].text
        problem_title = problem_title.strip()

        problem_link = table_col[3].find_element(By.TAG_NAME, "a")
        problem_link = problem_link.get_attribute("href")
        problem_link = problem_link.strip()

        language = table_col[4].text
        language = language.strip()

        verdict = table_col[5].text
        verdict = verdict.strip()

        run_time = table_col[6].text
        run_time = run_time.strip()

        mem_used = table_col[7].text
        mem_used = mem_used.strip()

        
        btn = table_col[0].find_element(By.CSS_SELECTOR, ".view-source")
        btn.click()
        time.sleep(2)
        

        table_data=[
            [f'*  @author: {author}', f'created: {created}'],
            [f'*  solution_verdict: {verdict}', f'language: {language}'],
            [f'*  run_time: {run_time}', f'memory_used: {mem_used}']
        ]
        printer = '/****************************************************************************************\n'
        for row in table_data:
            printer+=("{: <60} {: <50}".format(*row))+'\n'
        printer += f"*  problem: {problem_link}\n"
        printer +='****************************************************************************************/\n'
        #print(printer)
        
        
        code = driver.find_elements(By.TAG_NAME, "code")  
        for line in code:
            printer+=(line.text)
        
        
        # insurance
        if len(printer)<590:
            time.sleep(3)
            print("got one")
            close = driver.find_element(By.CSS_SELECTOR, ".close")
            close.click()
            time.sleep(2)
            continue
        
            
        
        for c in "\/:*?\"<>|": # folder name can't have these character
            problem_title = problem_title.replace(c, 'x')
        path = f'codeforces/{subid}({problem_title}).cpp'

        with open(path, 'w') as f:
            f.write(printer)
        
        
        close = driver.find_element(By.CSS_SELECTOR, ".close")
        close.click()
        
        
        count += 1
        print(f"page {i} sub {count} len {len(printer)}")
        time.sleep(1)
        ii += 1
# Out:
# page 141 sub 1 len 851
# page 141 sub 2 len 2350
# page 141 sub 3 len 2267
# page 141 sub 4 len 2363
# page 141 sub 5 len 2288
# page 141 sub 6 len 2282
# page 141 sub 7 len 2293
# page 141 sub 8 len 917
# page 141 sub 9 len 1472
# page 141 sub 10 len 1293
# page 141 sub 11 len 1278
# page 141 sub 12 len 1210
# page 141 sub 13 len 1210
# page 141 sub 14 len 1211
# page 141 sub 15 len 1188
# page 141 sub 16 len 1188
# page 141 sub 17 len 1187
# page 141 sub 18 len 1143
# page 141 sub 19 len 1141
# page 141 sub 20 len 1087
# page 141 sub 21 len 831
# page 141 sub 22 len 948
# page 141 sub 23 len 1799
# page 141 sub 24 len 1719
# page 141 sub 25 len 1378
# page 141 sub 26 len 882
# page 141 sub 27 len 1028
# page 141 sub 28 len 1676
# page 141 sub 29 len 1406
# page 141 sub 30 len 1012
# page 141 sub 31 len 1457
# page 141 sub 32 len 1457
# page 141 sub 33 len 1122
# page 141 sub 34 len 1122
# page 141 sub 35 len 740
# page 141 sub 36 len 996
# page 141 sub 37 len 735
# page 141 sub 38 len 1170
# page 141 sub 39 len 1227
# page 141 sub 40 len 1203
# page 141 sub 41 len 1205
# page 141 sub 42 len 1287
# page 141 sub 43 len 1275
# page 141 sub 44 len 1209
# page 141 sub 45 len 1171
# page 141 sub 46 len 1430
# page 141 sub 47 len 1083
# page 141 sub 48 len 1073
# page 141 sub 49 len 1107
# page 141 sub 50 len 1119
# page 142 sub 1 len 1236
# page 142 sub 2 len 1039
# page 142 sub 3 len 1078
# page 142 sub 4 len 1020
# page 142 sub 5 len 852
# page 142 sub 6 len 1439
# page 142 sub 7 len 1348
# page 142 sub 8 len 1328
# page 142 sub 9 len 830
# page 142 sub 10 len 842
# page 142 sub 11 len 1179
# page 142 sub 12 len 1199
# page 142 sub 13 len 1404
# page 142 sub 14 len 1106
# page 142 sub 15 len 1331
# page 142 sub 16 len 1343
# page 142 sub 17 len 1231
# page 142 sub 18 len 1406
# page 142 sub 19 len 1093
# page 142 sub 20 len 1089
# page 142 sub 21 len 1871
# page 142 sub 22 len 1856
# page 142 sub 23 len 1239
# page 142 sub 24 len 1157
# page 142 sub 25 len 1080
# page 142 sub 26 len 1051
# page 142 sub 27 len 1051
# page 142 sub 28 len 1121
# page 142 sub 29 len 1092
# page 142 sub 30 len 997
# page 142 sub 31 len 1024
# page 142 sub 32 len 1572
# page 142 sub 33 len 1572
# page 142 sub 34 len 1129
# page 142 sub 35 len 1545
# page 142 sub 36 len 1545
# page 142 sub 37 len 1139
# page 142 sub 38 len 880
# page 142 sub 39 len 947
# page 142 sub 40 len 948
# page 142 sub 41 len 988
# page 142 sub 42 len 1453
# page 142 sub 43 len 1453
# page 142 sub 44 len 961
# page 142 sub 45 len 1087
# page 142 sub 46 len 1453
# page 142 sub 47 len 799
# page 142 sub 48 len 751
# page 142 sub 49 len 741
# page 142 sub 50 len 730
# page 143 sub 1 len 722
# page 143 sub 2 len 771
# page 143 sub 3 len 850
# page 143 sub 4 len 730
# page 143 sub 5 len 727
# page 143 sub 6 len 1116
# got one
# page 143 sub 7 len 1438
# page 143 sub 8 len 1408
# page 143 sub 9 len 1009
# page 143 sub 10 len 757
# page 143 sub 11 len 757
# page 143 sub 12 len 778
# page 143 sub 13 len 707
# page 143 sub 14 len 690
# page 143 sub 15 len 714
# page 143 sub 16 len 719
# page 143 sub 17 len 1409
# page 143 sub 18 len 2271
# page 143 sub 19 len 2020
# page 143 sub 20 len 1768
# page 143 sub 21 len 1879
# page 143 sub 22 len 1875
# page 143 sub 23 len 1870
# page 143 sub 24 len 1763
# page 143 sub 25 len 1748
# page 143 sub 26 len 2402
# page 143 sub 27 len 990
# page 143 sub 28 len 1147
# page 143 sub 29 len 1263
# page 143 sub 30 len 1266
# page 143 sub 31 len 1472
# page 143 sub 32 len 751
# page 143 sub 33 len 1252
# page 143 sub 34 len 964
# page 143 sub 35 len 1131
# page 143 sub 36 len 1127
# page 143 sub 37 len 1324
# page 143 sub 38 len 2432
# page 143 sub 39 len 1119
# page 143 sub 40 len 1156
# page 143 sub 41 len 1005
# page 143 sub 42 len 1005
# page 143 sub 43 len 1006
# page 143 sub 44 len 833
# page 143 sub 45 len 2540
# page 143 sub 46 len 1015
# page 143 sub 47 len 1096
# page 143 sub 48 len 1386
# page 143 sub 49 len 1621
# page 143 sub 50 len 1095
# page 144 sub 1 len 1569
# page 144 sub 2 len 1122
# page 144 sub 3 len 1123
# page 144 sub 4 len 884
# page 144 sub 5 len 904
# page 144 sub 6 len 1207
# page 144 sub 7 len 1043
# page 144 sub 8 len 1690
# page 144 sub 9 len 1694
# page 144 sub 10 len 2540
# page 144 sub 11 len 1115
# page 144 sub 12 len 1072
# page 144 sub 13 len 1089
# page 144 sub 14 len 1467
# page 144 sub 15 len 1221
# page 144 sub 16 len 1226
# page 144 sub 17 len 1222
# page 144 sub 18 len 1603
# page 144 sub 19 len 879
# page 144 sub 20 len 1603
# page 144 sub 21 len 1587
# page 144 sub 22 len 1687
# page 144 sub 23 len 1599
# page 144 sub 24 len 1533
# page 144 sub 25 len 1121
# page 144 sub 26 len 1075
# page 144 sub 27 len 1019
# page 144 sub 28 len 1022
# page 144 sub 29 len 833
# page 144 sub 30 len 1378
# page 144 sub 31 len 1382
# page 144 sub 32 len 1434
# page 144 sub 33 len 1433
# page 144 sub 34 len 962
# page 144 sub 35 len 901
# page 144 sub 36 len 820
# page 144 sub 37 len 1530
# page 144 sub 38 len 1520
# page 144 sub 39 len 1511
# page 144 sub 40 len 940
# page 144 sub 41 len 874
# page 144 sub 42 len 1511
# page 144 sub 43 len 854
# page 144 sub 44 len 823
# page 144 sub 45 len 785
# page 144 sub 46 len 767
# page 144 sub 47 len 761
# page 144 sub 48 len 1020
# page 144 sub 49 len 2442
# page 144 sub 50 len 1061
# page 145 sub 1 len 1038
# page 145 sub 2 len 1345
# page 145 sub 3 len 1246
# page 145 sub 4 len 1053
# page 145 sub 5 len 1447
# page 145 sub 6 len 1447
