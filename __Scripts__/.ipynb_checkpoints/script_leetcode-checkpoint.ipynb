# %%
import os
import time

from selenium import webdriver
from selenium.webdriver.common.by import By

chromedriver_path = "C:\\Users\\Araf\\Desktop\\Script\\chromedriver_win32"
os.environ['PATH'] += chromedriver_path

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(40)

driver.get("https://leetcode.com/accounts/login/")
# do login manually

# %%
problem_list = []
def get_problem_list():
    # there are total 14 submission page
    for page in range(1,15):
        driver.get(f"https://leetcode.com/submissions/#/{page}")
        time.sleep(5)
        
        table_row = driver.find_elements(By.TAG_NAME, "tr")
        table_row = table_row[1:]
        
        for row in table_row:
            table_col = row.find_elements(By.TAG_NAME, "td")
            problem_list.append(table_col[1].text)

get_problem_list()
problem_list = list(set(problem_list))

# %%
# there are 100 problem in problem_list
lt=86
rt=90

for prb in range(lt, rt+1):
    
    p_title = problem_list[prb].strip()
    
    ln = problem_list[prb].lower()

    ln = ln.replace('-', ' ')
    ln = ln.replace('  ', ' ')
    ln = ln.replace('  ', ' ')
    
    ln = ln.replace(' ', '-')
    ln = ln.replace('\'', '')
    ln = ln.replace('(', '')
    ln = ln.replace(')', '')
    

    p_link = f"https://leetcode.com/problems/{ln}"
    driver.get(p_link)
    time.sleep(7)

    sub_btn = driver.find_element(By.CSS_SELECTOR, "a[href*='submission']")
    sub_btn.click()
    time.sleep(2)
    
    
    t_row = driver.find_elements(By.TAG_NAME, "tr")
    t_row = t_row[1:]
    
    created = []
    verdict = []
    run_time = []
    mem_used = []
    language = []
    sub_link = []
    
    for row in t_row:
        t_col = row.find_elements(By.TAG_NAME, "td")
        created.append(t_col[0].text.strip())
        verdict.append(t_col[1].text.strip())
        run_time.append(t_col[2].text.strip())
        mem_used.append(t_col[3].text.strip())
        language.append(t_col[4].text.strip())
        sub_link.append((t_col[1].find_element(By.CSS_SELECTOR, "a[href*='detail']")).get_attribute("href"))
    
    for i in range(len(sub_link)):
        driver.get(sub_link[i])
        time.sleep(7)
        code = driver.find_element(By.CSS_SELECTOR, ".ace_content").text
        
        
        table_data=[
            [f'*  @author: kzvd4729', f'created: {created[i]}'],
            [f'*  solution_verdict: {verdict[i]}', f'language: {language[i]}'],
            [f'*  run_time: {run_time[i]}', f'memory_used: {mem_used[i]}']
        ]
        printer = '/****************************************************************************************\n'
        for row in table_data:
            printer+=("{: <60} {: <50}".format(*row))+'\n'
        printer += f"*  problem: {p_link}\n"
        printer +='****************************************************************************************/\n'
        
        printer += code
        
        if len(printer)<590:
            print("got one bad")
            exit(0)
        
        for c in "\/:*?\"<>|.": # folder name can't have these character
            p_title = p_title.replace(c, 'x')
        
        current = f"leetcode/{p_title}"
        if not os.path.exists(current):
            os.mkdir(current)
            
        
        current = current+f'/{verdict[i]}'
        for j in range(1, 1000):
            if (j==1):
                now = current+'.cpp'
            else:
                now = current+f' ({j}).cpp'

            if not os.path.exists(now):
                with open(now, 'w') as f:
                    f.write(printer)
                f.close()

                break
        print(f"done {prb}:  {i+1}/{len(sub_link)}   {p_title}")
# Out:
# done 71:  1/1   Largest Magic Square
# done 72:  1/3   Maximum Width of Binary Tree
# done 72:  2/3   Maximum Width of Binary Tree
# done 72:  3/3   Maximum Width of Binary Tree
# done 73:  1/4   First Missing Positive
# done 73:  2/4   First Missing Positive
# done 73:  3/4   First Missing Positive
# done 73:  4/4   First Missing Positive
# done 74:  1/7   Remove Nth Node From End of List
# done 74:  2/7   Remove Nth Node From End of List
# done 74:  3/7   Remove Nth Node From End of List
# done 74:  4/7   Remove Nth Node From End of List
# done 74:  5/7   Remove Nth Node From End of List
# done 74:  6/7   Remove Nth Node From End of List
# done 74:  7/7   Remove Nth Node From End of List
# done 75:  1/1   Integer to Roman
# done 76:  1/1   Search in a Binary Search Tree
# done 77:  1/5   Min Cost Climbing Stairs
# done 77:  2/5   Min Cost Climbing Stairs
# done 77:  3/5   Min Cost Climbing Stairs
# done 77:  4/5   Min Cost Climbing Stairs
# done 77:  5/5   Min Cost Climbing Stairs
# done 78:  1/1   Swim in Rising Water
# done 79:  1/8   Remove Duplicates from Sorted List
# done 79:  2/8   Remove Duplicates from Sorted List
# done 79:  3/8   Remove Duplicates from Sorted List
# done 79:  4/8   Remove Duplicates from Sorted List
# done 79:  5/8   Remove Duplicates from Sorted List
# done 79:  6/8   Remove Duplicates from Sorted List
# done 79:  7/8   Remove Duplicates from Sorted List
# done 79:  8/8   Remove Duplicates from Sorted List
# done 80:  1/2   Longest Valid Parentheses
# done 80:  2/2   Longest Valid Parentheses
# done 81:  1/1   Rotated Digits
# done 82:  1/1   Best Time to Buy and Sell Stock
# done 83:  1/3   Rotate List
# done 83:  2/3   Rotate List
# done 83:  3/3   Rotate List
# done 84:  1/3   Stone Game VIII
# done 84:  2/3   Stone Game VIII
# done 84:  3/3   Stone Game VIII
# done 85:  1/1   Minimum Remove to Make Valid Parentheses
# got one bad
# done 86:  1/20   Longest Consecutive Sequence
# got one bad
# done 86:  2/20   Longest Consecutive Sequence
# got one bad
# done 86:  3/20   Longest Consecutive Sequence
# got one bad
# done 86:  4/20   Longest Consecutive Sequence
# got one bad
# done 86:  5/20   Longest Consecutive Sequence
# got one bad
# done 86:  6/20   Longest Consecutive Sequence
# got one bad
# done 86:  7/20   Longest Consecutive Sequence
# got one bad
# done 86:  8/20   Longest Consecutive Sequence
# got one bad
# done 86:  9/20   Longest Consecutive Sequence
# got one bad
# done 86:  10/20   Longest Consecutive Sequence
# got one bad
# done 86:  11/20   Longest Consecutive Sequence
# done 86:  12/20   Longest Consecutive Sequence
# done 86:  13/20   Longest Consecutive Sequence
# done 86:  14/20   Longest Consecutive Sequence
# done 86:  15/20   Longest Consecutive Sequence
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8476/3259334383.py in <module>
#      49     for i in range(len(sub_link)):
#      50         driver.get(sub_link[i])
# ---> 51         time.sleep(7)
#      52         code = driver.find_element(By.CSS_SELECTOR, ".ace_content").text
#      53
#
# KeyboardInterrupt:
